# %%
import omnifig as fig
fig.initialize()
# Out:
# Loaded deep_fake project!

# %%
import omnilearn

# %%
fig.get_current_project().xray('component')
# Out:
# mnist: src.data_loading.MNIST (Toy_Dataset)
# cifar: src.data_loading.CIFAR (Toy_Dataset)
# stdout: src.util._get_stdout() (auto)
# file: src.util._get_file(path) (auto)
# nn: src.deep_models.NeuralNetwork (Configurable, Module)
# net: src.deep_models.DeepModel (Configurable, Module)
# sgd-optim: src.deep_models.Optim (Configurable)
# nonlinearity: omnilearn.novo.modules.BasicNonlinearlity (RegistryBuilder)
# nonlin: omnilearn.novo.modules.BasicNonlinearlity (RegistryBuilder)
# normalization: omnilearn.novo.modules.BasicNormalization (RegistryBuilder)
# norm: omnilearn.novo.modules.BasicNormalization (RegistryBuilder)
# loss: omnilearn.novo.modules.BasicLoss (Builder)
# reshaper: omnilearn.novo.modules.Reshaper (Buildable, Module)
# linear: omnilearn.novo.modules.BasicLinear (Builder)
# dropout: omnilearn.novo.modules.BasicDropout (Builder)
# dense-layer: omnilearn.novo.modules.DenseLayer (Buildable, Module)
# mlp: omnilearn.novo.modules.MLP (Buildable, Function, Sequential)
# ...

# %%
from omnidata.datasets import MNIST
from omnilearn import util
# Out:
# WARNING: not registering config dir

# %%
dataroot = r'C:\Users\anwan\Documents\workspace'

# %%
dataset = MNIST(root=dataroot)

# %%
dataset.prepare()
# Out:
# C:\Users\anwan\anaconda3\lib\site-packages\torch\nn\functional.py:3609: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# mnist[60000]

# %%
dataset.observation_space
# Out:
# Pixels(C=1, H=32, W=32)

# %%
batch = dataset.get_batch()
batch
# Out:
# Batch{mnist}[64]

# %%
# b = batch.subset(20)
# Out:
# View{mnist}[20]

# %%
X, Y = batch['observation'], batch['target']
X.shape, Y.shape
# Out:
# (torch.Size([64, 1, 32, 32]), torch.Size([64]))

# %%
util.plot_imgs(X, );#titles=batch['target'].tolist());
